# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
metrics = ["Accuracy","Macro-F1-Score", "Macro-Precision", "Macro-Recall"]
zest_sane = [0.9841, 0.9775, 0.9720, 0.9830]
bi_lstm = [0.9752, 0.9556, 0.9514, 0.9598]
UniNet_no_tmartix = [0.9856,0.9792,0.9774,0.9811]
our_model = [0.9901, 0.9868, 0.9886, 0.9850]

x = np.arange(len(metrics))  # the label locations
width = 0.2  # the width of the bars, reduced for more spacing

fig, ax = plt.subplots(figsize=(10, 6),dpi=500)

# Adjusting bar positions to increase spacing between different groups
bars4 = ax.bar(x - 1.5*width, our_model, width, label='UniNet', hatch='xx', color='red')
bars3 = ax.bar(x - 0.5*width, UniNet_no_tmartix, width, label='UniNet w/o T-Matrix', hatch='--', color='pink')

bars1 = ax.bar(x + 0.5*width, zest_sane, width, label='SANE', hatch='//', color='#1f77b4')

bars2 = ax.bar(x + 1.5*width, bi_lstm, width, label='BiLSTM-iFP', hatch='\\\\', color='#2ca02c')



# Labels and titles
ax.set_ylabel('Scores', fontsize=16)
# ax.set_title('Performance Metrics Comparison', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=15)
ax.legend(fontsize=10)
ax.tick_params(axis='y', labelsize=13)
# Setting the y-axis limit to start from 0.94
ax.set_ylim([0.95, 0.995])

# Adding grid for better readability
ax.yaxis.grid(True, linestyle='--', which='both', color='grey', alpha=0.7)

# Adding value labels on top of the bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom',
                    fontsize=9)

add_labels(bars1)
add_labels(bars2)
add_labels(bars3)
add_labels(bars4)
# Save the figure
plt.tight_layout()
plt.savefig('performance_metrics_comparison.pdf', dpi=500)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
metrics = ["Accuracy", "Macro-Precision", "Macro-Recall", "Macro-F1-Score"]
zest_sane = [0.9841, 0.9720, 0.9830, 0.9775]
bi_lstm = [0.9752, 0.9514, 0.9598, 0.9556]
our_model = [0.9901, 0.9886, 0.9850, 0.9868]

# X axis
x = np.arange(len(metrics))

# Plotting
fig, ax = plt.subplots(figsize=(12, 8), dpi=300)

# Bar width
width = 0.25

# Colors
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']

# Bars with different hatching styles and brighter colors
bars3 = ax.bar(x + width, our_model, width, label='UniNet', hatch='x', color='red')
bars1 = ax.bar(x - width, zest_sane, width, label='ZEST-SANE', hatch='//', color='lightblue')
bars2 = ax.bar(x, bi_lstm, width, label='Bi-LSTM', hatch='\\\\', color='lightgreen')

# Labels and titles
ax.set_ylabel('Scores', fontsize=18)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=16)
ax.legend(fontsize=16)

# Setting the y-axis limit to start from 0.935
ax.set_ylim([0.935, 1.0])

# Adding grid for better readability
ax.yaxis.grid(True, linestyle='--', which='both', color='grey', alpha=0.7)
ax.tick_params(axis='y', labelsize=16)
# Adding value labels on top of the bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom',
                    fontsize=14)

add_labels(bars1)
add_labels(bars2)
add_labels(bars3)

# Save the figure
plt.tight_layout()
plt.savefig('performance_metrics_comparison.pdf', format='pdf', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
metrics = ["Accuracy","Macro-F1-Score",  "Macro-Recall","Macro-Precision"]
zest_sane = [0.9007, 0.9104, 0.9302, 0.8914]
bi_lstm = [0.8657, 0.8641, 0.8538, 0.8746]
UniNet_no_tmartix_packet = [0.9178,0.9196,0.9402,0.8999]
our_model = [0.9398, 0.9400, 0.9438, 0.9363]
UniNet_no_tmartix_flow = [0.7581,0.7649,0.7721, 0.7583] 
x = np.arange(len(metrics))  # the label locations
width = 0.2  # the width of the bars, reduced for more spacing

fig, ax = plt.subplots(figsize=(10, 6),dpi=500)

# Adjusting bar positions to increase spacing between different groups
bars4 = ax.bar(x - 1.5*width, our_model, width, label='UniNet', hatch='xx', color='red')
bars3 = ax.bar(x - 0.5*width, UniNet_no_tmartix_packet, width, label='UniNet w/o T-Matrix', hatch='--', color='pink')
bars5 = ax.bar(x - 0.5*width, UniNet_no_tmartix_flow, width, label='UniNet w/o T-Matrix', hatch='--', color='pink')
bars1 = ax.bar(x + 0.5*width, zest_sane, width, label='SANE', hatch='//', color='#1f77b4')

bars2 = ax.bar(x + 1.5*width, bi_lstm, width, label='BiLSTM-iFP', hatch='\\\\', color='#2ca02c')



# Labels and titles
ax.set_ylabel('Scores', fontsize=16)
# ax.set_title('Performance Metrics Comparison', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=15)
ax.legend(fontsize=10)
ax.tick_params(axis='y', labelsize=13)
# Setting the y-axis limit to start from 0.94
ax.set_ylim([0.75, 0.96])

# Adding grid for better readability
ax.yaxis.grid(True, linestyle='--', which='both', color='grey', alpha=0.7)

# Adding value labels on top of the bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom',
                    fontsize=9)

add_labels(bars1)
add_labels(bars2)
add_labels(bars3)
add_labels(bars4)
# Save the figure
plt.tight_layout()
plt.savefig('performance_metrics_comparison_minority_classes.pdf', dpi=500)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 18
#      16 # Adjusting bar positions to increase spacing between different groups
#      17 bars4 = ax.bar(x - 1.5*width, our_model, width, label='UniNet', hatch='xx', color='red')
# ---> 18 bars3 = ax.bar(x - 0.5*width, UniNet_no_tmartix, width, label='UniNet w/o T-Matrix', hatch='--', color='pink')
#      20 bars1 = ax.bar(x + 0.5*width, zest_sane, width, label='SANE', hatch='//', color='#1f77b4')
#      22 bars2 = ax.bar(x + 1.5*width, bi_lstm, width, label='BiLSTM-iFP', hatch='\\\\', color='#2ca02c')
#
# NameError: name 'UniNet_no_tmartix' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
metrics = ["Accuracy","Macro-F1-Score","Macro-Precision"]
zest_sane = [0.9007, 0.9104,  0.8914]
bi_lstm = [0.8657, 0.8641, 0.8746]
UniNet_no_tmartix = [0.9178,0.9196,0.8999]
our_model = [0.9398, 0.9400, 0.9363]

x = np.arange(len(metrics))  # the label locations
width = 0.18  # the width of the bars, reduced for more spacing

fig, ax = plt.subplots(figsize=(10, 6),dpi=500)

# Adjusting bar positions to increase spacing between different groups
bars4 = ax.bar(x - 1.5*width, our_model, width, label='UniNet', hatch='xx', color='red')
bars3 = ax.bar(x - 0.5*width, UniNet_no_tmartix, width, label='UniNet w/o T-Matrix', hatch='--', color='pink')

bars1 = ax.bar(x + 0.5*width, zest_sane, width, label='SANE', hatch='//', color='#1f77b4')

bars2 = ax.bar(x + 1.5*width, bi_lstm, width, label='BiLSTM-iFP', hatch='\\\\', color='#2ca02c')



# Labels and titles
ax.set_ylabel('Scores', fontsize=16)
# ax.set_title('Performance Metrics Comparison', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=15)
ax.legend(fontsize=14)
ax.tick_params(axis='y', labelsize=13)
# Setting the y-axis limit to start from 0.94
ax.set_ylim([0.85, 0.975])

# Adding grid for better readability
ax.yaxis.grid(True, linestyle='--', which='both', color='grey', alpha=0.7)

# Adding value labels on top of the bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom',
                    fontsize=9)

add_labels(bars1)
add_labels(bars2)
add_labels(bars3)
add_labels(bars4)
# Save the figure
plt.tight_layout()
plt.savefig('performance_metrics_comparison_minority_classes——three.pdf', dpi=500)
plt.show()
